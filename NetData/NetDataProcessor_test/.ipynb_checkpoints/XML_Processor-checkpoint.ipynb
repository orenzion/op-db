# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../../')
import myenvvar
from bs4 import BeautifulSoup
import pymysql
import glob
from sqlalchemy import create_engine
import ntpath

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user=myenvvar.db_vars['user'],
                               pw=myenvvar.db_vars['password'],
                               db=myenvvar.db_vars['db']),encoding = 'utf8')

# %%
db = pymysql.connect("localhost",myenvvar.db_vars['user'] ,myenvvar.db_vars['password'] ,myenvvar.db_vars['db'])

# %%
cursor = db.cursor()

# %%
tags_list = ['id_krn','shm_krn','tkf_divuach','id_natun','shm_krn','erech_natun','achuz']

# %%
all_files_list = glob.glob(r'C:\Users\orenz\Desktop\op_db\NetData\pensyanet_perut_male\*.xml')

# %%
all_files_list[:5]
# Out:
# ['C:\\Users\\orenz\\Desktop\\op_db\\NetData\\pensyanet_perut_male\\pensyanet_2017_01_perut.xml',
#  'C:\\Users\\orenz\\Desktop\\op_db\\NetData\\pensyanet_perut_male\\pensyanet_2017_02_perut.xml',
#  'C:\\Users\\orenz\\Desktop\\op_db\\NetData\\pensyanet_perut_male\\pensyanet_2017_03_perut.xml',
#  'C:\\Users\\orenz\\Desktop\\op_db\\NetData\\pensyanet_perut_male\\pensyanet_2017_04_perut.xml',
#  'C:\\Users\\orenz\\Desktop\\op_db\\NetData\\pensyanet_perut_male\\pensyanet_2017_05_perut.xml']

# %%
new_files_list = all_files_list
new_files_list[:5]
# Out:
# ['C:\\Users\\orenz\\Desktop\\op_db\\NetData\\pensyanet_perut_male\\pensyanet_2017_01_perut.xml',
#  'C:\\Users\\orenz\\Desktop\\op_db\\NetData\\pensyanet_perut_male\\pensyanet_2017_02_perut.xml',
#  'C:\\Users\\orenz\\Desktop\\op_db\\NetData\\pensyanet_perut_male\\pensyanet_2017_03_perut.xml',
#  'C:\\Users\\orenz\\Desktop\\op_db\\NetData\\pensyanet_perut_male\\pensyanet_2017_04_perut.xml',
#  'C:\\Users\\orenz\\Desktop\\op_db\\NetData\\pensyanet_perut_male\\pensyanet_2017_05_perut.xml']

# %%
#ntpath.basename(files_list[0])

# %%
#len([item.text for item in soup.find_all('id')])

# %%
len(new_files_list)
# Out:
# 41

# %%
len(tags_list)
# Out:
# 7

# %% [markdown]
# # test

# %%
with open(r'C:\\Users\\orenz\\Desktop\\op_db\\NetData\\pensyanet_perut_male\\pensyanet_2017_01_perut.xml','r',encoding='utf8') as file:
    handler = file.read()
    soup = BeautifulSoup(handler)

# %%
rows = soup.find_all('row')

# %%
rows[0]
# Out:
# <row>
# <id_krn>1560</id_krn>
# <shm_krn>איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 25% במדדי מניות</shm_krn>
# <tkf_divuach>201701</tkf_divuach>
# <id_natun>105</id_natun>
# <shm_natun>פח"ק/פר"י</shm_natun>
# <erech_natun>39.26</erech_natun>
# <achuz>8.5340</achuz>
# </row>

# %%
rows_arr = []
for row in rows:
    row_arr = []
    for tag in tags_list:
        cell = row.find(tag)
        if cell:
            row_arr.append(cell.text)
        else:
            row_arr.append(cell)
    
    rows_arr.append(row_arr)

# %%
df = pd.DataFrame(np.array(rows_arr),columns=tags_list)

# %%
df.head()
# Out:
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201701
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201701
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201701
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201701
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201701
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       39.26
# 1      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.20
# 2      555  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -1.75
# 3     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       27.32
# 4     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       35.28
#
#      achuz
# 0   8.5340
# 1   0.0440
# 2  -0.3810
# 3   5.9380
# 4     7.67

# %%
df['file_name'] = 'pensyanet_2017_01_perut.xml'

# %%
res = df.to_sql('pnet_perut', con = engine, if_exists = 'append',index=False)
# Out:
# C:\Users\orenz\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF9\\xF2\\xE5\\xEF \\xF7...' for column 'VARIABLE_VALUE' at row 1")
#   result = self._query(query)

# %%
#for row in rows_arr:
#    for cell in row:
#        if cell == None:
#            print("x")

# %%
len(rows)
# Out:
# 754

# %%
rows[0]
# Out:
# <row>
# <id>101</id>
# <shm_kupa>הראל אג"ח עד 25% מניות </shm_kupa>
# <taarich_hafakat_hadoch>29/08/2019</taarich_hafakat_hadoch>
# <sug_kupa>תגמולים ואישית לפיצויים</sug_kupa>
# <shm_taagid_sholet>הראל השקעות בביטוח ושירותים פיננסיים בע"מ</shm_taagid_sholet>
# <sug_taagid_sholet>קבוצות ביטוח</sug_taagid_sholet>
# <shm_hevra_menahelet>הראל פנסיה וגמל בע"מ</shm_hevra_menahelet>
# <taarich_hakama>01/04/1979</taarich_hakama>
# <uchlusiyat_yaad>כלל האוכלוסיה</uchlusiyat_yaad>
# <hitmahut_rashit>אג"ח</hitmahut_rashit>
# <hitmahut_mishnit>משולב מניות</hitmahut_mishnit>
# <tkufat_divuach>201701</tkufat_divuach>
# <hafkadot_llo_haavarot>12.70</hafkadot_llo_haavarot>
# <mshichot_llo_haavarot>56.97</mshichot_llo_haavarot>
# <haavarot_bein_hakupot>-43.55</haavarot_bein_hakupot>
# <tzvira_neto>-87.82</tzvira_neto>
# <yitrat_nchasim_lsof_tkufa>11582.25</yitrat_nchasim_lsof_tkufa>
# <shiur_dmei_nihul_aharon>0.69</shiur_dmei_nihul_aharon>
# <shiur_d_nihul_aharon_hafkadot>0.52</shiur_d_nihul_aharon_hafkadot>
# <tsua_nominalit_bruto_hodshit>0.31</tsua_nominalit_bruto_hodshit>
# <tsua_mitzt_mi_thilat_shana>0.31</tsua_mitzt_mi_thilat_shana>
# <tsua_memuzaat_36_hodashim>0.33</tsua_memuzaat_36_hodashim>
# <tsua_memuzaat_60_hodashim>0.49</tsua_memuzaat_60_hodashim>
# <tsua_mitztaberet_36_hodashim>12.53</tsua_mitztaberet_36_hodashim>
# <tsua_mitztaberet_60_hodashim>33.93</tsua_mitztaberet_60_hodashim>
# <tsua_shnatit_memuzaat_3_shanim>4.01</tsua_shnatit_memuzaat_3_shanim>
# <tsua_shnatit_memuzaat_5_shanim>6.02</tsua_shnatit_memuzaat_5_shanim>
# <stiat_teken_36_hodashim>1.14</stiat_teken_36_hodashim>
# <stiat_teken_60_hodashim>1.17</stiat_teken_60_hodashim>
# <matzav_divuach>דווח</matzav_divuach>
# <alpha_shnatit>2.28</alpha_shnatit>
# <sharp_anaf>0.58</sharp_anaf>
# <sharp_kol_hakupot>0.78</sharp_kol_hakupot>
# <sharp_ribit_hasrat_sikun>1.08</sharp_ribit_hasrat_sikun>
# <yahas_nezilut>76.90</yahas_nezilut>
# <mispar_kupa_av>0</mispar_kupa_av>
# <num_hevra>512267592</num_hevra>
# </row>

# %%
for file_ in all_files_list:
    with open(file_,'r',encoding='utf8') as file:
        handler = file.read()
        soup = BeautifulSoup(handler)
    rows = soup.find_all('row')
    rows_arr = []
    for row in rows:
        row_arr = []
        for tag in tags_list:
            cell = row.find(tag)
            if cell:
                row_arr.append(cell.text)
            else:
                row_arr.append(cell)
    
        rows_arr.append(row_arr)
        
    df = pd.DataFrame(np.array(rows_arr),columns=tags_list)    
    df['file_name'] = ntpath.basename(file_)
    print(df.head())
    
    # Insert whole DataFrame into MySQL
    res = df.to_sql('pnet_perut', con = engine, if_exists = 'append',index=False)
# Out:
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201701
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201701
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201701
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201701
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201701
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       39.26
# 1      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.20
# 2      555  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -1.75
# 3     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       27.32
# 4     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       35.28
#
#      achuz                    file_name
# 0   8.5340  pensyanet_2017_01_perut.xml
# 1   0.0440  pensyanet_2017_01_perut.xml
# 2  -0.3810  pensyanet_2017_01_perut.xml
# 3   5.9380  pensyanet_2017_01_perut.xml
# 4     7.67  pensyanet_2017_01_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201702
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201702
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201702
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201702
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201702
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       42.74
# 1      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.20
# 2      555  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -0.43
# 3     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       27.89
# 4     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       39.60
#
#      achuz                    file_name
# 0   9.0360  pensyanet_2017_02_perut.xml
# 1   0.0420  pensyanet_2017_02_perut.xml
# 2  -0.0920  pensyanet_2017_02_perut.xml
# 3   5.8960  pensyanet_2017_02_perut.xml
# 4   8.3710  pensyanet_2017_02_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201703
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201703
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201703
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201703
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201703
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      230.14
# 1      106  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.03
# 2      555  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -0.31
# 3     5050  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -2.19
# 4     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       57.94
#
#      achuz                    file_name
# 0  23.3780  pensyanet_2017_03_perut.xml
# 1   0.0030  pensyanet_2017_03_perut.xml
# 2  -0.0310  pensyanet_2017_03_perut.xml
# 3  -0.2230  pensyanet_2017_03_perut.xml
# 4   5.8860  pensyanet_2017_03_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201704
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201704
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201704
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201704
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201704
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       78.91
# 1      106  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.01
# 2      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.49
# 3      555  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -0.87
# 4     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       60.48
#
#      achuz                    file_name
# 0   7.8950  pensyanet_2017_04_perut.xml
# 1   0.0010  pensyanet_2017_04_perut.xml
# 2   0.0490  pensyanet_2017_04_perut.xml
# 3  -0.0870  pensyanet_2017_04_perut.xml
# 4   6.0510  pensyanet_2017_04_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201705
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201705
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201705
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201705
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201705
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       94.85
# 1      106  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.01
# 2      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.48
# 3      554  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.97
# 4      555  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -0.78
#
#      achuz                    file_name
# 0     9.24  pensyanet_2017_05_perut.xml
# 1   0.0010  pensyanet_2017_05_perut.xml
# 2   0.0470  pensyanet_2017_05_perut.xml
# 3   0.0940  pensyanet_2017_05_perut.xml
# 4  -0.0760  pensyanet_2017_05_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201706
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201706
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201706
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201706
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201706
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       94.34
# 1      106  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -2.12
# 2      554  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.44
# 3      555  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -0.98
# 4     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       61.50
#
#      achuz                    file_name
# 0   9.0130  pensyanet_2017_06_perut.xml
# 1  -0.2030  pensyanet_2017_06_perut.xml
# 2   0.0420  pensyanet_2017_06_perut.xml
# 3  -0.0930  pensyanet_2017_06_perut.xml
# 4   5.8760  pensyanet_2017_06_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201707
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201707
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201707
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201707
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201707
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        4.15
# 1      106  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.03
# 2      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       17.22
# 3      555  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -0.64
# 4     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       60.21
#
#      achuz                    file_name
# 0   0.4660  pensyanet_2017_07_perut.xml
# 1   0.0030  pensyanet_2017_07_perut.xml
# 2   1.9340  pensyanet_2017_07_perut.xml
# 3  -0.0720  pensyanet_2017_07_perut.xml
# 4   6.7620  pensyanet_2017_07_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201708
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201708
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201708
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201708
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201708
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      108.90
# 1      106  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.04
# 2      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        8.12
# 3      555  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -0.82
# 4     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       66.61
#
#      achuz                    file_name
# 0  10.9230  pensyanet_2017_08_perut.xml
# 1   0.0040  pensyanet_2017_08_perut.xml
# 2   0.8150  pensyanet_2017_08_perut.xml
# 3  -0.0820  pensyanet_2017_08_perut.xml
# 4   6.6820  pensyanet_2017_08_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      
# 1      106  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       -4.26
# 2      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        4.72
# 3      554  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.01
# 4     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      179.27
#
#     achuz                    file_name
# 0  4.3410  pensyanet_2019_08_perut.xml
# 1   -0.17  pensyanet_2019_08_perut.xml
# 2  0.1880  pensyanet_2019_08_perut.xml
# 3  0.0010  pensyanet_2019_08_perut.xml
# 4  7.1560  pensyanet_2019_08_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201909
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201909
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201909
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201909
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201909
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       99.54
# 1      106  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        2.98
# 2      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        1.46
# 3     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      181.97
# 4     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      199.73
#
#     achuz                    file_name
# 0  3.9260  pensyanet_2019_09_perut.xml
# 1  0.1170  pensyanet_2019_09_perut.xml
# 2  0.0580  pensyanet_2019_09_perut.xml
# 3  7.1770  pensyanet_2019_09_perut.xml
# 4  7.8780  pensyanet_2019_09_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201910
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201910
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201910
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201910
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201910
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      125.65
# 1      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        1.47
# 2     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      177.10
# 3     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      205.80
# 4     5907  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...     1092.63
#
#      achuz                    file_name
# 0   4.9010  pensyanet_2019_10_perut.xml
# 1   0.0570  pensyanet_2019_10_perut.xml
# 2   6.9080  pensyanet_2019_10_perut.xml
# 3   8.0270  pensyanet_2019_10_perut.xml
# 4  42.6180  pensyanet_2019_10_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201911
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201911
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201911
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201911
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201911
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      132.45
# 1      106  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      -13.50
# 2      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        1.32
# 3     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      185.73
# 4     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      205.13
#
#      achuz                    file_name
# 0   5.0960  pensyanet_2019_11_perut.xml
# 1  -0.5190  pensyanet_2019_11_perut.xml
# 2   0.0510  pensyanet_2019_11_perut.xml
# 3   7.1470  pensyanet_2019_11_perut.xml
# 4   7.8930  pensyanet_2019_11_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201912
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201912
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201912
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201912
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      201912
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      278.55
# 1      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        1.50
# 2     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      214.71
# 3     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      234.92
# 4     5907  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...     1300.52
#
#      achuz                    file_name
# 0   9.1920  pensyanet_2019_12_perut.xml
# 1   0.0490  pensyanet_2019_12_perut.xml
# 2   7.0850  pensyanet_2019_12_perut.xml
# 3   7.7520  pensyanet_2019_12_perut.xml
# 4  42.9160  pensyanet_2019_12_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202001
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202001
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202001
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202001
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202001
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      130.54
# 1      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        6.47
# 2     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      221.32
# 3     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      238.13
# 4     5907  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...     1388.08
#
#      achuz                    file_name
# 0   4.1780  pensyanet_2020_01_perut.xml
# 1   0.2070  pensyanet_2020_01_perut.xml
# 2   7.0840  pensyanet_2020_01_perut.xml
# 3   7.6220  pensyanet_2020_01_perut.xml
# 4  44.4310  pensyanet_2020_01_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202002
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202002
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202002
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202002
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202002
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.05
# 1      106  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       13.82
# 2      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       20.75
# 3     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      198.91
# 4     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      215.68
#
#     achuz                    file_name
# 0  0.0020  pensyanet_2020_02_perut.xml
# 1  0.4780  pensyanet_2020_02_perut.xml
# 2  0.7180  pensyanet_2020_02_perut.xml
# 3  6.8850  pensyanet_2020_02_perut.xml
# 4  7.4660  pensyanet_2020_02_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202003
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202003
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202003
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202003
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202003
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       70.70
# 1      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       24.84
# 2     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      212.09
# 3     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      195.27
# 4     5907  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...     1255.01
#
#      achuz                    file_name
# 0   2.4350  pensyanet_2020_03_perut.xml
# 1   0.8550  pensyanet_2020_03_perut.xml
# 2   7.3040  pensyanet_2020_03_perut.xml
# 3   6.7250  pensyanet_2020_03_perut.xml
# 4  43.2230  pensyanet_2020_03_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202004
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202004
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202004
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202004
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202004
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       76.56
# 1      106  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...        0.05
# 2      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...       25.30
# 3     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      217.64
# 4     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      241.81
#
#     achuz                    file_name
# 0  2.5280  pensyanet_2020_04_perut.xml
# 1  0.0020  pensyanet_2020_04_perut.xml
# 2  0.8350  pensyanet_2020_04_perut.xml
# 3  7.1860  pensyanet_2020_04_perut.xml
# 4  7.9850  pensyanet_2020_04_perut.xml
#   id_krn                                            shm_krn tkf_divuach  \
# 0   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202005
# 1   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202005
# 2   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202005
# 3   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202005
# 4   1560  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      202005
#
#   id_natun                                            shm_krn erech_natun  \
# 0      105  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      102.33
# 1      511  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...          18
# 2     5901  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      215.44
# 3     5904  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...      253.01
# 4     5907  איילון מיטב פנסיה מקיפה פאסיבי- מדדי אג"ח עד 2...     1323.31
#
#      achuz                    file_name
# 0   3.3290  pensyanet_2020_05_perut.xml
# 1   0.5860  pensyanet_2020_05_perut.xml
# 2   7.0090  pensyanet_2020_05_perut.xml
# 3   8.2310  pensyanet_2020_05_perut.xml
# 4  43.0520  pensyanet_2020_05_perut.xml

# %%
#

# %%
with open(r'C:\Users\orenz\Desktop\op_db\NetData\gemelnet_maslul_clali\gemelnet_2017_01_maslul_klali.xml','r',encoding='utf8') as file:
    handler = file.read()
    soup = BeautifulSoup(handler)

# %%
#tag_list = [tag.name for tag in soup.find_all()]
##tag_list = tag_list[6:43]
#tag_list

# %%
arr = []
for tag in tags_list:
    temp_arr = [item.text for item in soup.find_all(tag)]
    arr.append(temp_arr)

# %%
df = pd.DataFrame(np.array(arr).T,columns=tags_list)

# %%
#df['taarich_hafakat_hadoch'] = pd.to_datetime(df['taarich_hafakat_hadoch'])

# %%
df_cols = ['ID','Name','Date','Diposits (No Moving)','Redemptions (No Moving)',\
        'Moving between funds','Net Accumulation','Total Fair Value','ROW.SHIUR_DMEI_NIHUL_AHARON',\
        'Yield - Monthly Nominal','Yield - Cumulative  beginning of the year','ROW.MATZAV_DIVUACH',\
        'Sharp Industry','Sharp - All Funds','Sharp - Free Risk','Liquidity Ratio','ROW.SHIUR_D_NIHUL_AHARON_HAFKADOT',\
        'ROW.SHIUR_D_NIHUL_AHARON_NCHASIM','ROW.ODEF_GIRAON_ACTUARI_AHARON','ROW.ODEF_GIRAON_ACTUARI_LETKUFA',\
        'ROW.TSUA_NOM_HASHKAOT_HOFSHIOT','Yield - Average 36 Months','Yield - Average 60 Months',\
        'Yield - Cumulative 36 Months','Yield - Cumulative 60 Months','Yield - Average 3 Years',\
        'Yield - Average 5 Years','SD 36 Months','SD 60 Months','Alpha - Year','Beta - Ta100',\
        'ROW.BETA_AGACH_KONTZERNIOT_TZMUDOT.Element:Text','ROW.BETA_AGACH_MEM_LO_TZMUDOT.Element:Text',\
        'ROW.BETA_AGACH_MEMSHALTIOT_TZMUDOT.Element:Text','ROW.BETA_HUTZ_LAARETZ.Element:Text','ROW.R_SQUARED.Element:Text']
