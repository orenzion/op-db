# %%
import openpyxl
import os
import glob
import numpy as np
import datetime
import pandas as pd

# %%
#os.chdir("/mydir")
files_list = []
for file in glob.glob("*.xlsx"):
    files_list.append(file)
    print(file)
# Out:
# השקעה-יעד לפרישה 2045 2019.xlsx

# %%
file_name_with_extension = files_list[0]

# %%
filename, extension = os.path.splitext(file_name_with_extension)

# %%
if extension.lower() == '.xlsx':
    workbook = openpyxl.load_workbook(filename=file_name_with_extension)

# %% [markdown]
# # create empty dataframe

# %%
df = pd.DataFrame(columns=["file_name","fund_name","year","month","title","sub_title","value"])

# %% [markdown]
# # basic row structure

# %%
basic_row_struct = {"file_name":None,
                    "fund_name":None,
                   "year":None,
                   "month":None,
                   "title":None,
                   "sub_title":None,
                   "value":None}

# %% [markdown]
# # add file name to struct

# %%
basic_row_struct['file_name'] = file_name_with_extension

# %% [markdown]
# # get fund name

# %%
fund_name = workbook.sheetnames[0]
basic_row_struct["fund_name"] = fund_name

# %%
# get work sheet
worksheet = workbook[fund_name]

# %% [markdown]
# # get year xlsx

# %%
if worksheet.cell(4,1).value != None and type(worksheet.cell(4,1).value) == int:
    year = worksheet.cell(4,1).value
elif worksheet.cell(4,2).value != None and type(worksheet.cell(4,2).value) == int:
    year = worksheet.cell(4,2).value
else:
    col1 = 7
    col2 = 8
    for row_num in range(1,17):
        val1 = worksheet.cell(row_num,col1).value
        val2 = worksheet.cell(row_num,col2).value
        
        if val1 != None:
            if type(val1) == datetime.datetime:
                year = val1.year
                break
            if type(val1) == int:
                year = val1
                break
            arr1 = [int(s) for s in val1.split() if s.isdigit()]
            if arr1:
                year = arr1[0]
                break
        if val2 != None:
            if type(val2) == datetime.datetime:
                year = val2.year
                break
            if type(val2) == int:
                year = val2
                break
            arr2 = [int(s) for s in val2.split() if s.isdigit()]
            if arr2:
                year = arr2[0]
                break

if len(str(year)) > 4:
    year = int(str(year)[:-1])

# %%
basic_row_struct['year'] = year
year
# Out:
# 2017

# %% [markdown]
# # find top corner xlsx:

# %%
exit_loop = False
for row in worksheet.iter_rows(max_row=18,max_col=4):
    for cell in row:
        if type(cell.value) == str and cell.value.find('מזומנים') != -1 :
            start_row = cell.row
            start_col = cell.column
            print(cell.value)
            exit_loop = True
            break
    if exit_loop == True:
        break
# Out:
# מזומנים ושווי מזומנים

# %% [markdown]
# # find last row xlsx:

# %%
exit_loop = False
for row in worksheet.iter_rows(min_row=25,max_row=37,max_col=4):
    for cell in row:
        if type(cell.value) == str and cell.value.find('רווח') != -1 :
            end_row = cell.row
            print(cell.value)
            exit_loop = True
            break
    if exit_loop == True:
        break
# Out:
# סה"כ רווח השקעתי לתקופה (אלפי ₪)

# %% [markdown]
# # iterate table and get values xlsx:

# %%
for row in worksheet.iter_rows(min_row=start_row, max_row=end_row, min_col=start_col, max_col=start_col+24):
    i = 0
    month = 1
    for cell in row:
        if i == 0:
            basic_row_struct['title'] = cell.value
        elif i%2 == 1:
            basic_row_struct['sub_title'] = 'תרומה לתשואה'
            basic_row_struct['month'] = month
            basic_row_struct['value'] = cell.value
        else:
            basic_row_struct['sub_title'] = 'שיעור מסך הנכסים'
            basic_row_struct['month'] = month
            basic_row_struct['value'] = cell.value
            month+=1
        if i!= 0:
            df = df.append(basic_row_struct,ignore_index=True)
            print(basic_row_struct)
        i+=1
# Out:
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 1, 'title': 'מזומנים ושווי מזומנים', 'sub_title': 'תרומה לתשואה', 'value':
-05}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 4, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.002300902736220739}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 5, 'title': 'השקעות אחרות', 'sub_title': 'תרומה לתשואה', 'value': 0.00022910844100427992}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 5, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.001272226419014802}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 6, 'title': 'השקעות אחרות', 'sub_title': 'תרומה לתשואה', 'value': -0.000130519706860554}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 6, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.000372330773239144}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 7, 'title': 'השקעות אחרות', 'sub_title': 'תרומה לתשואה', 'value': -2.6592743884270523e-05}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 7, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.003080078554707594}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 8, 'title': 'השקעות אחרות', 'sub_title': 'תרומה לתשואה', 'value': -1.1198821446897039e-05}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 8, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.003498125419366467}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 9, 'title': 'השקעות אחרות', 'sub_title': 'תרומה לתשואה', 'value': -2.044998641726648e-05}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 9, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.003067093276558184}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 10, 'title': 'השקעות אחרות', 'sub_title': 'תרומה לתשואה', 'value': -1.8215110109962273e-05}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 10, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.001361701321877134}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 11, 'title': 'השקעות אחרות', 'sub_title': 'תרומה לתשואה', 'value': -6.399520072102376e-07}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 11, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0002846866082708082}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 12, 'title': 'השקעות אחרות', 'sub_title': 'תרומה לתשואה', 'value': -3.9855579658709125e-05}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 12, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0010506912727099452}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 1, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.003075520624865824}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 1, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.0000000000000009}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 2, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.004378177421221041}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 2, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.0000000000000002}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 3, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.003750116110492252}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 3, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.9999999999999998}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 4, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.009341153134869495}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 4, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 1}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 5, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.008473913700852043}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 5, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 1}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 6, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': -0.0030156219693066033}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 6, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.9999999999999998}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 7, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.010691355396585278}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 7, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.9999999999999998}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 8, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.003540242689568318}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 8, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.0000000000000009}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 9, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.0034957603668690496}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 9, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.9999999999999993}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 10, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.007302512720473997}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 10, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 1}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 11, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.0055011111882246055}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 11, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.9999999999999999}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 12, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.007172349377668308}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 12, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.9999999999999999}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 1, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': 35803.00124823098}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 1, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 2, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': 50796.36026372601}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 2, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 3, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': 43292.19733372901}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 3, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 4, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': 107345.36555005201}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 4, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 5, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': 97852.34137752195}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 5, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 6, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': -34747.066965883016}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 6, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 7, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': 122628.33822191296}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 7, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 8, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': 40787.303022258966}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 8, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 9, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': 40270.87839557398}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 9, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 10, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': 84124.79588660003}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 10, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 11, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': 63327.31734975096}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 11, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 12, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'תרומה לתשואה', 'value': 82532.53472372104}
# {'file_name': '101_201712.xlsx', 'fund_name': 'פרסום מרכיבי תשואה', 'year': 2017, 'month': 12, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ₪)', 'sub_title': 'שיעור מסך הנכסים', 'value': 'תא ללא תוכן. המשך תוכן בתא הבא.'}

# %%
df.head()
# Out:
#          file_name           fund_name  year month                  title  \
# 0  101_201712.xlsx  פרסום מרכיבי תשואה  2017     1  מזומנים ושווי מזומנים
# 1  101_201712.xlsx  פרסום מרכיבי תשואה  2017     2  מזומנים ושווי מזומנים
# 2  101_201712.xlsx  פרסום מרכיבי תשואה  2017     3  מזומנים ושווי מזומנים
# 3  101_201712.xlsx  פרסום מרכיבי תשואה  2017     4  מזומנים ושווי מזומנים
# 4  101_201712.xlsx  פרסום מרכיבי תשואה  2017     5  מזומנים ושווי מזומנים
#
#           sub_title        value
# 0      תרומה לתשואה -0.000164963
# 1  שיעור מסך הנכסים    0.0590539
# 2      תרומה לתשואה -0.000386577
# 3  שיעור מסך הנכסים    0.0714497
# 4      תרומה לתשואה  -7.2415e-05

# %%
df.tail()
# Out:
#                  file_name fund_name  year month  \
# 247  השקעה-מניות 2019.xlsx   גיליון1  2019     8
# 248  השקעה-מניות 2019.xlsx   גיליון1  2019     9
# 249  השקעה-מניות 2019.xlsx   גיליון1  2019    10
# 250  השקעה-מניות 2019.xlsx   גיליון1  2019    11
# 251  השקעה-מניות 2019.xlsx   גיליון1  2019    12
#
#                                   title         sub_title    value
# 247  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים     None
# 248  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה -12208.3
# 249  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים     None
# 250  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה  22573.9
# 251  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים     None
