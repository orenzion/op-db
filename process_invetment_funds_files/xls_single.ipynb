# %%
import xlrd
import os
import glob
import numpy as np
import datetime
import pandas as pd

# %%
#os.chdir("/mydir")
files_list = []
for file in glob.glob("*.xls"):
    files_list.append(file)
    print(file)
# Out:
# תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls

# %%
file_name_with_extension = files_list[0]

# %%
filename, extension = os.path.splitext(file_name_with_extension)

# %%
if extension.lower() == '.xls':
    workbook = xlrd.open_workbook(filename=file_name_with_extension)

# %% [markdown]
# # create empty dataframe

# %%
df = pd.DataFrame(columns=["file_name","fund_name","year","month","title","sub_title","value"])

# %% [markdown]
# # basic row structure

# %%
basic_row_struct = {"file_name":None,
                    "fund_name":None,
                   "year":None,
                   "month":None,
                   "title":None,
                   "sub_title":None,
                   "value":None}

# %% [markdown]
# # add file name to struct

# %%
basic_row_struct['file_name'] = file_name_with_extension

# %% [markdown]
# # get fund name

# %%
fund_name = workbook.sheet_names()[0]
basic_row_struct["fund_name"] = fund_name

# %%
# get work sheet
worksheet = workbook.sheets()[0]

# %% [markdown]
# # get year xlsx

# %%
if worksheet.cell(4,1).value != None and type(worksheet.cell(4,1).value) == int:
    year = worksheet.cell(4,1).value
elif worksheet.cell(4,2).value != None and type(worksheet.cell(4,2).value) == int:
    year = worksheet.cell(4,2).value
else:
    col1 = 7
    col2 = 8
    for row_num in range(1,17):
        val1 = worksheet.cell(row_num,col1).value
        val2 = worksheet.cell(row_num,col2).value
        
        if val1 != None:
            if type(val1) == datetime.datetime:
                year = val1.year
                break
            if type(val1) == int:
                year = val1
                break
            arr1 = [int(s) for s in val1.split() if s.isdigit()]
            if arr1:
                year = arr1[0]
                break
        if val2 != None:
            if type(val2) == datetime.datetime:
                year = val2.year
                break
            if type(val2) == int:
                year = val2
                break
            arr2 = [int(s) for s in val2.split() if s.isdigit()]
            if arr2:
                year = arr2[0]
                break

if len(str(year)) > 4:
    year = int(str(year)[:-1])

# %%
basic_row_struct['year'] = year
year
# Out:
# 2017

# %% [markdown]
# # find top corner xlsx:

# %%
exit_loop = False
for r in range(18):
    for c in range(4):
        cell = worksheet.cell(r,c)
        if type(cell.value) == str and cell.value.find('מזומנים') != -1:
            start_row = r
            start_col = c
            print(cell.value)
            exit_loop = True
            break
    if exit_loop == True:
        break
# Out:
# מזומנים ושווה מזומנים

# %% [markdown]
# # find last row xlsx:

# %%
exit_loop = False
for r in range(25,37):
    for c in range(0,4):
        cell = worksheet.cell(r,c)
        if type(cell.value) == str and cell.value.find('רווח') != -1 :
            end_row = r
            print(cell.value)
            exit_loop = True
            break
    if exit_loop == True:
        break
# Out:
# סה"כ רווח השקעתי לתקופה (אלפי ש"ח)

# %% [markdown]
# # iterate table and get values xlsx:

# %%
for r in range(start_row,end_row+1):
    i = 0
    month = 1
    for c in range(start_col, start_col+25):
        cell = worksheet.cell(r,c)  
        if i == 0:
            basic_row_struct['title'] = cell.value
        elif i%2 == 1:
            basic_row_struct['sub_title'] = 'תרומה לתשואה'
            basic_row_struct['month'] = month
            basic_row_struct['value'] = cell.value
        else:
            basic_row_struct['sub_title'] = 'שיעור מסך הנכסים'
            basic_row_struct['month'] = month
            basic_row_struct['value'] = cell.value
            month+=1
        if i!= 0:
            df = df.append(basic_row_struct,ignore_index=True)
            print(basic_row_struct)
        i+=1
# Out:
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.91}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': -0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.35}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.35}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.55}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': -0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.93}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': -0.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.5}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': 0.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.17}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.76}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.81}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': 0.82}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.1}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'מזומנים ושווה מזומנים', 'sub_title': 'שיעור מסך הנכסים', 'value': 2.5}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 61.52}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': -0.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 60.48}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.17}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 59.98}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.3}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 60.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.31}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 58.67}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': -0.16}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 59.17}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.28}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 59.47}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.24}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 59.13}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': -0.09}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 59.42}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 59.99}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.18}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.21}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 59.22}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.18}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'אגח משלתיות סחירות ולא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 57.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.07}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.08}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.08}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.08}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'תעודות חוב מסחריות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.44}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.44}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.45}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.46}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.46}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.47}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.48}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.48}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.49}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.5}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.5}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'תעודות חוב מסחריות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.51}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 23.69}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': -0.08}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 23.91}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': -0.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 23.9}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.26}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 24.55}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.12}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 24.47}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': -0.15}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 24.48}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.26}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 24.4}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.19}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 23.95}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': -0.08}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 23.56}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 23.53}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.09}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.06}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 23.55}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'אגח קונצרניות סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 24.26}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.37}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.37}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.52}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.67}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.62}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.64}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.64}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.65}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.66}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 1.65}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.67}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'אגח קונצרניות לא סחירות', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.6}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': -0.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'מניות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'מניות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.83}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.84}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.86}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.88}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.89}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': -0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.9}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.93}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.95}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': -0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.95}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': 0.95}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.03}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'תעודות סל', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'תעודות סל', 'sub_title': 'שיעור מסך הנכסים', 'value': 1.05}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': -0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 4.28}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': -0.05}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 4.32}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': -0.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 4.66}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': 0.04}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 4.85}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': -0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 4.86}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': -0.07}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 4.92}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': 0.11}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 5.1}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': 0.08}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 5.26}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': -0.08}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 5.23}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': 5.47}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': -0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 5.72}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'קרנות נאמנות', 'sub_title': 'תרומה לתשואה', 'value': -0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'קרנות נאמנות', 'sub_title': 'שיעור מסך הנכסים', 'value': 5.8}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'קרנות השקעה', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'קרנות השקעה', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'קרנות השקעה', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'קרנות השקעה', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'קרנות השקעה', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'קרנות השקעה', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'קרנות השקעה', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'קרנות השקעה', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'קרנות השקעה', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'קרנות השקעה', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'קרנות השקעה', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'קרנות השקעה', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# ...
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'השקעות אחרות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'השקעות אחרות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'השקעות אחרות', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'השקעות אחרות', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': -0.02}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.22}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.07}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.07}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.01}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'חייבים וזכאים שונים', 'sub_title': 'תרומה לתשואה', 'value': 0.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'חייבים וזכאים שונים', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.05}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.13}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': -0.08}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.22}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.67}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.5}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': -0.34}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.66}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.52}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': -0.16}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 0.31}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.3}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'תשואה חודשית', 'sub_title': 'תרומה לתשואה', 'value': 0.25}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'תשואה חודשית', 'sub_title': 'שיעור מסך הנכסים', 'value': 100.0}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': 1273.96}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 1, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': 1273.96}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': -743.5}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 2, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': -743.5}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': 2014.47}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 3, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': 2014.47}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': 6002.28}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 4, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': 6002.28}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': 4392.45}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 5, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': 4392.45}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': -3002.46}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 6, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': -3002.46}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': 5607.59}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 7, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': 5607.59}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': 4395.14}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 8, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': 4395.14}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': -1371.14}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 9, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': -1371.14}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': 2558.91}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 10, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': 2558.91}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': 2443.43}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 11, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': 2443.43}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'תרומה לתשואה', 'value': 2000.51}
# {'file_name': 'תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls', 'fund_name': 'תשואות לפי אפיק V3', 'year': 2017, 'month': 12, 'title': 'סה"כ רווח השקעתי לתקופה (אלפי ש"ח)', 'sub_title': 'שיעור מסך הנכסים', 'value': 2000.51}

# %%
df[:24]
# Out:
#                                        file_name           fund_name  year  \
# 0   תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 1   תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 2   תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 3   תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 4   תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 5   תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 6   תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 7   תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 8   תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 9   תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 10  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 11  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 12  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 13  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 14  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 15  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 16  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 17  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 18  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 19  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 20  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 21  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 22  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 23  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
#
#    month                  title         sub_title  value
# 0      1  מזומנים ושווה מזומנים      תרומה לתשואה   0.00
# 1      1  מזומנים ושווה מזומנים  שיעור מסך הנכסים   0.91
# 2      2  מזומנים ושווה מזומנים      תרומה לתשואה  -0.01
# 3      2  מזומנים ושווה מזומנים  שיעור מסך הנכסים   1.35
# 4      3  מזומנים ושווה מזומנים      תרומה לתשואה   0.00
# 5      3  מזומנים ושווה מזומנים  שיעור מסך הנכסים   1.35
# 6      4  מזומנים ושווה מזומנים      תרומה לתשואה   0.00
# 7      4  מזומנים ושווה מזומנים  שיעור מסך הנכסים   0.55
# 8      5  מזומנים ושווה מזומנים      תרומה לתשואה  -0.01
# 9      5  מזומנים ושווה מזומנים  שיעור מסך הנכסים   1.93
# 10     6  מזומנים ושווה מזומנים      תרומה לתשואה  -0.02
# 11     6  מזומנים ושווה מזומנים  שיעור מסך הנכסים   1.50
# 12     7  מזומנים ושווה מזומנים      תרומה לתשואה   0.02
# 13     7  מזומנים ושווה מזומנים  שיעור מסך הנכסים   1.17
# 14     8  מזומנים ושווה מזומנים      תרומה לתשואה   0.00
# 15     8  מזומנים ושווה מזומנים  שיעור מסך הנכסים   1.76
# 16     9  מזומנים ושווה מזומנים      תרומה לתשואה   0.00
# 17     9  מזומנים ושווה מזומנים  שיעור מסך הנכסים   1.81
# 18    10  מזומנים ושווה מזומנים      תרומה לתשואה   0.82
# 19    10  מזומנים ושווה מזומנים  שיעור מסך הנכסים   0.00
# 20    11  מזומנים ושווה מזומנים      תרומה לתשואה   0.00
# 21    11  מזומנים ושווה מזומנים  שיעור מסך הנכסים   1.10
# 22    12  מזומנים ושווה מזומנים      תרומה לתשואה   0.00
# 23    12  מזומנים ושווה מזומנים  שיעור מסך הנכסים   2.50

# %%
df[-24:]
# Out:
#                                         file_name           fund_name  year  \
# 504  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 505  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 506  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 507  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 508  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 509  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 510  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 511  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 512  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 513  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 514  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 515  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 516  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 517  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 518  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 519  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 520  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 521  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 522  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 523  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 524  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 525  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 526  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
# 527  תשואה  לפי  אפיק -_20171231_v1_1332_7261.xls  תשואות לפי אפיק V3  2017
#
#     month                               title         sub_title    value
# 504     1  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה  1273.96
# 505     1  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים  1273.96
# 506     2  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה  -743.50
# 507     2  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים  -743.50
# 508     3  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה  2014.47
# 509     3  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים  2014.47
# 510     4  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה  6002.28
# 511     4  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים  6002.28
# 512     5  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה  4392.45
# 513     5  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים  4392.45
# 514     6  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה -3002.46
# 515     6  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים -3002.46
# 516     7  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה  5607.59
# 517     7  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים  5607.59
# 518     8  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה  4395.14
# 519     8  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים  4395.14
# 520     9  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה -1371.14
# 521     9  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים -1371.14
# 522    10  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה  2558.91
# 523    10  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים  2558.91
# 524    11  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה  2443.43
# 525    11  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים  2443.43
# 526    12  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)      תרומה לתשואה  2000.51
# 527    12  סה"כ רווח השקעתי לתקופה (אלפי ש"ח)  שיעור מסך הנכסים  2000.51
